# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("importedd")
# Out:
# importedd

# %%
# Load the CSV file
df = pd.read_csv('data/flood_prediction.csv')
print(f"Dataset loaded. Total rows: {df.shape[0]}, Columns: {df.shape[1]}")
# Out:
# Dataset loaded. Total rows: 115, Columns: 11

# %%
df.head()
# Out:
#    Temp  Humidity  Cloud Cover  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec  \
# 0    29        70           30  3248.6     73.4    386.2   2122.8    666.1
# 1    28        75           40  3326.6      9.3    275.7   2403.4    638.2
# 2    28        75           42  3271.2     21.7    336.3   2343.0    570.1
# 3    29        71           44  3129.7     26.7    339.4   2398.2    365.3
# 4    31        74           40  2741.6     23.4    378.5   1881.5    458.1
#
#       avgjune    sub  flood
# 0  274.866667  649.9      0
# 1  130.300000  256.4      1
# 2  186.200000  308.9      0
# 3  366.066667  862.5      0
# 4  283.400000  586.9      0

# %%
df.tail()
# Out:
#      Temp  Humidity  Cloud Cover  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec  \
# 110    28        71           30  3035.1     66.2    313.5   2209.1    446.3
# 111    29        71           37  2151.1     18.3    287.4   1535.6    309.8
# 112    30        74           42  3255.4     43.9    218.5   2561.2    431.8
# 113    31        71           31  3046.4     14.9    364.5   2164.8    502.1
# 114    28        71           34  2600.6      8.9    465.9   1514.7    611.1
#
#         avgjune    sub  flood
# 110  262.833333  664.3      0
# 111  143.433333  335.0      0
# 112  347.566667  923.4      1
# 113  151.466667  203.4      0
# 114  187.866667  361.8      0

# %%
df.info()

# %%
df.describe()
print("-----")
df.isnull().sum()
print("---")
df.duplicated().sum()
# Out:
# -----
# ---
# np.int64(0)

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df['ANNUAL'], bins=20, kde=True, color='steelblue')
plt.title('Distribution of Annual Rainfall')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Count')
plt.show()

# %%
numeric_df = df.select_dtypes(include=[np.number])
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Weather Features and Flood Risk')
plt.show()

# %%
plt.figure(figsize=(8, 4))
flood_counts = df['flood'].value_counts()
sns.barplot(x=flood_counts.index, y=flood_counts.values, palette='Set2')
plt.title('Flood Risk Distribution')
plt.xlabel('Flood Risk (0=No Flood, 1=Flood)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\syedf\AppData\Local\Temp\ipykernel_14912\1303997310.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=flood_counts.index, y=flood_counts.values, palette='Set2')
